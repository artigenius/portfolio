# %% [markdown]
# <a href="https://colab.research.google.com/github/artigenius/portfolio/blob/main/%D0%9C%D0%BE%D1%80%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5_%D0%BE%D1%81%D0%BD%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F_%D0%B8%D0%BD%D1%84%D0%BE%D1%86%D1%8B%D0%B3%D0%B0%D0%BD%D0%B5_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer

# %%
pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# Импорт для загрузки данных
nltk.download('punkt')
nltk.download('snowball_data')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package snowball_data to /root/nltk_data...
# True

# %% [markdown]
# Контент: https://drive.google.com/file/d/1_IzZupSReQbq4oCzoibbsJOMl0mkMRpc/view?usp=sharing

# %%
# !gdown https://drive.google.com/drive/folders/1v4IsiDCFMWufdoa42sEeYMCHpLh0GtMT?usp=sharing --folder
# Out:
# Retrieving folder contents
# Processing file 1YwauGD8pjvuPle3GemYp1ZdoaOiozz53 Алекс Лесли.docx.txt
# Processing file 149JmjuAMJmBSGnFmtO8TuFD1Niu5riwc Александра Митрошина.txt
# Processing file 1E3qkkqW1pGcxwjgYtLx1fNqEkJ9_LqOh Анастасия Шевченко.txt
# Processing file 18pfqCOZsgnWCf--WH3xP4mMo0PQryrN4 Андрей Петров.txt
# Processing file 10eLBdrKY7B8YLrvaTzhXMFIcCIG5LGtv Артем Сенаторов.txt
# Processing file 15jAx8QYTi7vypDGnX7GVzPXMFU1JUppr Аяз Шабутдинов.txt
# Processing file 1IrGGwWhmmhZY2YlT8HyzjmlwDHoR5eUQ Боня.txt
# Processing file 1YF_60nw02DrpZsG7tEBkcSM6lbzBgsLA Валерия Чекалина.txt
# Processing file 1BtKElmO9vqkXNqJufM68a_O4o0fnDxsB Гоар.txt
# Processing file 1a7vCTcMJYzb8c-CGHuMwh_v-uPpajtxq Гусейн Гасанов.txt
# Processing file 1Z0t7HWi73pZZrN1IfN5Ey_jiBuHW0Kvg Елена Блиновская.txt
# Processing file 1qRVX9-yGTLRk6K3J7rB6-gWEZ0NiEwBu Лев Вожеватов.txt
# Processing file 1Lh3ZUdnVUGqJZpBBasSMxapXqkR9BKFF Настя Рыбка.txt
# Processing file 1rl4P-aC5JVq9Y7kaBfBK-Ixr-F8oC2Cu Оксана Самойлова.txt
# Processing file 1iitaXeLpKj0yrhrbIoXWa0H2WK8nSBbn Сергей Попов .txt
# Processing file 1ELlJDLJmG1LZ15rmwPMx0uW6IwvVevc6 Яна Рудковская.txt
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Error:
#
# 	'NoneType' object has no attribute 'groups'
#
# To report issues, please visit https://github.com/wkentaro/gdown/issues.

# %%
import os
os.listdir('/content/info')
# Out:
# []

# %%
# Функция для подсчета категорий в тексте
def count_categories_in_text(text, category_dict):
    tokens = word_tokenize(text.lower())  # Получаем токены

    # Инициализация стеммера
    stemmer = SnowballStemmer("russian")

    # Лемматизация токенов
    lemmatized_tokens = [stemmer.stem(token) for token in tokens]

    # Создаем словарь для подсчета
    category_counts = {category: 0 for category in category_dict}

    # Проходимся по каждому токену и считаем вхождения категорий
    for token in lemmatized_tokens:
        for category, keywords in category_dict.items():
            for keyword in keywords:
                #if token.startswith(keyword):  # Сравниваем с лемматизированными словами словаря
                if token == keyword:
                    category_counts[category] += 1

    return category_counts



# Функция для чтения файла с несколькими текстами
'''
def process_multiple_texts(file_path, separator, category_dict):
    with open(file_path, 'r', encoding='utf-8') as file:
        texts = file.read().split(separator)

    data = []
    # Обработка каждого текста
    for index, text in enumerate(texts, start=1):
        category_counts = count_categories_in_text(text, category_dict)
        data.append(category_counts)

    df = pd.DataFrame(data, index=range(1, len(texts)+1))  # Создаем DataFrame
    return df
'''

# Функция для обработки всех файлов
def process_multiple_files(folder_path, category_dict):
    data = []
    filenames = os.listdir(folder_path)  # Получаем список файлов в папке

    # Обработка каждого файла
    for filename in filenames:
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()
            category_counts = count_categories_in_text(text, category_dict)
            data.append(category_counts)

    df = pd.DataFrame(data, index=[filename.split('.')[0] for filename in filenames])  # Создаем DataFrame
    return df

# %% [markdown]
# Словарь: https://drive.google.com/file/d/10uB7P0v-XbOIbqBm5atHx3emb_w1JyRJ/view?usp=sharing

# %%
# !gdown --id 10uB7P0v-XbOIbqBm5atHx3emb_w1JyRJ
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=10uB7P0v-XbOIbqBm5atHx3emb_w1JyRJ
# To: /content/moral_lexicon.txt
# 100% 6.61k/6.61k [00:00<00:00, 24.7MB/s]

# %%
# Загрузка словаря
# Чтение файла со словарем категорий
categories_file = '/content/moral_lexicon.txt'

# Создание словаря категорий
category_dict = {}
with open(categories_file, 'r', encoding='utf-8') as file:
    lines = file.readlines()
    for line in lines:
        parts = line.strip().split(':')  # Разбиваем строку по двоеточию
        category_number = parts[0].strip()
        category_keywords = parts[1].strip().split(',')  # Разбиваем ключевые слова по запятой
        category_dict[category_number] = category_keywords

# Выводим словарь категорий
for category, keywords in category_dict.items():
    print(f"{category}: {keywords}")
# Out:
# category_01: ['безопасн', 'мирн', 'гуман', 'человечн', 'сочувств', 'сопережива', 'сострада', 'забот', 'попечени', 'защи', 'спаса', 'спасите', 'спаст', 'спасл', 'спасал', 'приют', 'дружб', 'друг', 'друга', 'другу', 'друз', 'помощ', 'помог', 'опек', 'оберег', 'предостере']
# category_02: ['вред', 'страда', 'войн', 'воев', 'воен', 'воин', 'непримирим', 'борьб', 'насил', 'избиени', 'избит', 'избив', 'побои', 'изнасилова', 'издева', 'пытк', 'пыток', 'пытать', 'пытал', 'пытали', 'пытают', 'травл', 'травить', 'травят', 'глумит', 'глумлен', 'обид', 'обиж', 'уби', 'опасн', 'жесток', 'брутальн', 'ожесточен', 'живодер', 'бессердечн', 'негуманн', 'бесчеловечн', 'оскорбл', 'оскорбит', 'навред', 'повред', 'повреж', 'разруш', 'уничтож', 'губи', 'сгуби', 'загуби', 'испорт', 'ущерб', 'отказ', 'подави', 'атак', 'напад', 'истреб', 'отверг', 'поврежд', 'рани', 'ранен']
# category_03: ['справед', 'равен', 'равны', 'правосуд', 'беспристрастн', 'порядочн', 'равноправ', 'заслужен', 'оправд', 'взаимн', 'непредубежден', 'эгалитар', 'права', 'право', 'равнознач', 'равноценн', 'объективн', 'толерант', 'уравновешен', 'взвешенн', 'непредвзят', 'обоснованн', 'честн']
# category_04: ['несправедлив', 'неравенств', 'предубежден', 'бесправ', 'необъективн', 'фанат', 'дискриминац', 'непропорц', 'пристрастн', 'нетолерантн', 'нетерпим', 'тенденциозн', 'нечестн', 'ложь', 'лжив', 'врань', 'врать', 'вру', 'врешь', 'врет', 'врем', 'врут', 'врал', 'совру', 'соврешь', 'соврет', 'соврал', 'соврать', 'клевет', 'бессовестн', 'разобщ', 'преференц', 'фаворит', 'сегрегац', 'пренебреж', 'унизительн', 'унижени', 'унижа']
# category_05: ['сообща', 'нацио', 'родин', 'отчизн', 'семья', 'семьи', 'семье', 'семей', 'групп', 'лояль', 'преданн', 'патриот', 'совместн', 'сообществ', 'общественн', 'товарищ', 'кадр', 'коллектив', 'сообща', 'единство', 'объедин', 'собрат', 'союз', 'солидарн', 'последовател', 'член', 'порук', 'отряд', 'сторонник']
# category_06: ['иностранн', 'чужд', 'враг', 'враж', 'предател', 'предал', 'предав', 'измен', 'изменник', 'изменял', 'изменяю', 'изменяют', 'изменяет', 'изменять', 'перебежчи', 'вероломн', 'нелояльн', 'индивидуалист', 'отступни', 'вероотступн', 'дезертир', 'обман', 'лицемер', 'ерети', 'шпион', 'террори', 'иммигрант']
# category_07: ['подчин', 'послуш', 'повин', 'закон', 'законн', 'закона', 'законы', 'закону', 'правов', 'почтительн', 'почет', 'почтен', 'чтить', 'чту', 'вежлив', 'признан', 'порядок', 'порядк', 'отец', 'отеческ', 'мать', 'материнск', 'материнств', 'традиц', 'иерарх', 'авторитет', 'позвол', 'разреш', 'разрешени', 'статус', 'лидер', 'руководит', 'правител', 'командир', 'командова', 'вождь', 'каста', 'касты', 'касте', 'кастов', 'должност', 'звани', 'уступчив', 'соглас', 'приказыва', 'приказал', 'приказ', 'приказа', 'приказу', 'приказом', 'приказы', 'приказов', 'приказам', 'верховн', 'управл', 'контрол', 'власт', 'покорн', 'служ', 'уступит', 'уступать', 'преклон', 'благогов', 'исполн']
# category_08: ['дерзк', 'вызывающ', 'неповин', 'невежлив', 'хамств', 'хамит', 'хамят', 'хамск', 'мятеж', 'восстани', 'возраж', 'инакомысл', 'сверг', 'ниспроверг', 'низверг', 'неуваж', 'непочтитель', 'нагруб', 'груб', 'неподчин', 'непокорн', 'непослуш', 'подстрекат', 'агитир', 'агитатор', 'недисциплинирован', 'незаконн', 'беззакон', 'повстан', 'восстав', 'игнориров', 'диссидент', 'неверующ', 'ерети', 'нонконформ', 'противостоя', 'протест', 'отверг', 'отвержен', 'обвин', 'бунт', 'препятствов']
# category_09: ['благочест', 'праведн', 'чист', 'непорочн', 'свят', 'целомудр', 'свящ', 'безгреш', 'нравственн', 'воздержан', 'дева', 'деве', 'девы', 'девственниц', 'девственност', 'невинн', 'аскет', 'скромн', 'стыд', 'пристойн', 'благопристойн', 'добродетел', 'изысканн', 'благородн', 'прилич', 'безупречн', 'неиспорчен', 'церков']
# category_10: ['отвратительн', 'отвращен', 'омерзен', 'омерзительн', 'развращ', 'распущенн', 'пороч', 'порок', 'гряз', 'непристойн', 'неподобающ', 'неприличин', 'грех', 'греш', 'прегреш', 'безнравственн', 'потаскух', 'шлюх', 'гадост', 'пакост', 'ничтож', 'нечестив', 'богохуль', 'кощунств', 'вульгарн', 'пошлы', 'пошлост', 'неприятны', 'извращен', 'промискуитет', 'похот', 'прелюбоде', 'любовни', 'дебош', 'оскверн', 'вандализм', 'проститут', 'бесстыд', 'невоздержан', 'распутн', 'распутств', 'разврат', 'растлен', 'мерзост', 'мерзк', 'дрянн', 'похабн', 'позор', 'запятнанн', 'бесчести', 'обесчест', 'безнравств', 'запятна', 'совращ', 'соблазн', 'надругат', 'презренн', 'презир']
# category_11: ['добродетельн', 'совест', 'мораль', 'этич', 'этик', 'ценност', 'добры', 'доброт', 'добряк', 'добросовест', 'поучительн', 'наставл', 'нравоучен', 'канон', 'вероучен', 'догм', 'доблест', 'достоинств', 'достойн', 'идеал', 'похвальн', 'одобряемы', 'одобряемо', 'одобряема', 'надлежащ', 'корректн', 'неправильн', 'недобросовестн', 'зло', 'зла', 'злу', 'злой', 'злое', 'злая', 'злые', 'злоба', 'злобы', 'злобе', 'злобу', 'злост', 'злобн', 'аморальн', 'бессовестн', 'дурно', 'обид', 'обиж', 'преступ']

# %%
folder_path = "/content/info"

result_df = process_multiple_files(folder_path, category_dict)
result_df
# Out:
#                       category_01  category_02  category_03  category_04  \
# Боня                           36            7            1            7
# Яна Рудковская                 22            1            3            4
# Александра Митрошина           10            0            4            3
# Валерия Чекалина               24            0            5            9
# Гоар                            9            0            2            1
# Гусейн Гасанов                  5            0            0            1
# Оксана Самойлова               16            4            3            5
# Аяз Шабутдинов                 11            0            0            5
# Андрей Петров                  32            2            5           16
# Алекс Лесли                    16            1            0            1
# Елена Блиновская               40            2            1           10
# Анастасия Шевченко             43            4            1           26
# Лев Вожеватов                  14            0            1           12
# Сергей Попов                   14           11            4            4
# Артем Сенаторов                 7            2            0           10
# Настя Рыбка                    13            1            3            3
#
#                       category_05  category_06  category_07  category_08  \
# Боня                            0            0            9            0
# Яна Рудковская                  2            1            5            1
# Александра Митрошина            1            1            1            0
# Валерия Чекалина                2            2            5            6
# Гоар                            1            0            1            1
# Гусейн Гасанов                  0            0            1            0
# Оксана Самойлова                1            3            4            0
# Аяз Шабутдинов                  4            0           11            0
# Андрей Петров                   2            2            6            2
# Алекс Лесли                     1            1            6            0
# Елена Блиновская                0            3            7            0
# Анастасия Шевченко              6            6           11            0
# Лев Вожеватов                   2            3            8            3
# Сергей Попов                    5            4            4            4
# Артем Сенаторов                 1            1           11            1
# Настя Рыбка                     7            0            4            1
#
#                       category_09  category_10  category_11
# Боня                            0            0            8
# Яна Рудковская                  0            0            3
# Александра Митрошина            1            0            1
# Валерия Чекалина                1            0            2
# Гоар                            3            0            4
# Гусейн Гасанов                  0            0            0
# Оксана Самойлова                1            0            5
# Аяз Шабутдинов                  0            1            5
# Андрей Петров                   0            0            5
# Алекс Лесли                     0            2            0
# Елена Блиновская                0            2            7
# Анастасия Шевченко              1            0            7
# Лев Вожеватов                   1            4           13
# Сергей Попов                    5            1            3
# Артем Сенаторов                 0            0            2
# Настя Рыбка                     0            0            5

# %%
result_df
# Out:
#                       category_01  category_02  category_03  category_04  \
# Боня                           36            7            1            7
# Яна Рудковская                 22            1            3            4
# Александра Митрошина           10            0            4            3
# Валерия Чекалина               24            0            5            9
# Гоар                            9            0            2            1
# Гусейн Гасанов                  5            0            0            1
# Оксана Самойлова               16            4            3            5
# Аяз Шабутдинов                 11            0            0            5
# Андрей Петров                  32            2            5           16
# Алекс Лесли                    16            1            0            1
# Елена Блиновская               40            2            1           10
# Анастасия Шевченко             43            4            1           26
# Лев Вожеватов                  14            0            1           12
# Сергей Попов                   14           11            4            4
# Артем Сенаторов                 7            2            0           10
# Настя Рыбка                    13            1            3            3
#
#                       category_05  category_06  category_07  category_08  \
# Боня                            0            0            9            0
# Яна Рудковская                  2            1            5            1
# Александра Митрошина            1            1            1            0
# Валерия Чекалина                2            2            5            6
# Гоар                            1            0            1            1
# Гусейн Гасанов                  0            0            1            0
# Оксана Самойлова                1            3            4            0
# Аяз Шабутдинов                  4            0           11            0
# Андрей Петров                   2            2            6            2
# Алекс Лесли                     1            1            6            0
# Елена Блиновская                0            3            7            0
# Анастасия Шевченко              6            6           11            0
# Лев Вожеватов                   2            3            8            3
# Сергей Попов                    5            4            4            4
# Артем Сенаторов                 1            1           11            1
# Настя Рыбка                     7            0            4            1
#
#                       category_09  category_10  category_11
# Боня                            0            0            8
# Яна Рудковская                  0            0            3
# Александра Митрошина            1            0            1
# Валерия Чекалина                1            0            2
# Гоар                            3            0            4
# Гусейн Гасанов                  0            0            0
# Оксана Самойлова                1            0            5
# Аяз Шабутдинов                  0            1            5
# Андрей Петров                   0            0            5
# Алекс Лесли                     0            2            0
# Елена Блиновская                0            2            7
# Анастасия Шевченко              1            0            7
# Лев Вожеватов                   1            4           13
# Сергей Попов                    5            1            3
# Артем Сенаторов                 0            0            2
# Настя Рыбка                     0            0            5

# %%
columns_new = {
    'category_01': 'Забота',
    'category_02': 'Вред',
    'category_03': 'Справедливость',
    'category_04': 'Несправедливость',
    'category_05': 'Лояльность',
    'category_06': 'Нелояльность',
    'category_07': 'Уважение',
    'category_08': 'Неуважение',
    'category_09': 'Чистота',
    'category_10': 'Порочность',
    'category_11': 'Мораль'
}

# Переименовываем столбцы и сохраняем изменения в исходном DataFrame
result_df.rename(columns=columns_new, inplace=True)

# %%
info_moral = result_df.T

# %%
info_moral
# Out:
#                   Боня  Яна Рудковская  Александра Митрошина  \
# Забота              36              22                    10
# Вред                 7               1                     0
# Справедливость       1               3                     4
# Несправедливость     7               4                     3
# Лояльность           0               2                     1
# Нелояльность         0               1                     1
# Уважение             9               5                     1
# Неуважение           0               1                     0
# Чистота              0               0                     1
# Порочность           0               0                     0
# Мораль               8               3                     1
#
#                   Валерия Чекалина  Гоар  Гусейн Гасанов  Оксана Самойлова  \
# Забота                          24     9               5                16
# Вред                             0     0               0                 4
# Справедливость                   5     2               0                 3
# Несправедливость                 9     1               1                 5
# Лояльность                       2     1               0                 1
# Нелояльность                     2     0               0                 3
# Уважение                         5     1               1                 4
# Неуважение                       6     1               0                 0
# Чистота                          1     3               0                 1
# Порочность                       0     0               0                 0
# Мораль                           2     4               0                 5
#
#                   Аяз Шабутдинов  Андрей Петров  Алекс Лесли  \
# Забота                        11             32           16
# Вред                           0              2            1
# Справедливость                 0              5            0
# Несправедливость               5             16            1
# Лояльность                     4              2            1
# Нелояльность                   0              2            1
# Уважение                      11              6            6
# Неуважение                     0              2            0
# Чистота                        0              0            0
# Порочность                     1              0            2
# Мораль                         5              5            0
#
#                   Елена Блиновская  Анастасия Шевченко  Лев Вожеватов  \
# Забота                          40                  43             14
# Вред                             2                   4              0
# Справедливость                   1                   1              1
# Несправедливость                10                  26             12
# Лояльность                       0                   6              2
# Нелояльность                     3                   6              3
# Уважение                         7                  11              8
# Неуважение                       0                   0              3
# Чистота                          0                   1              1
# Порочность                       2                   0              4
# Мораль                           7                   7             13
#
#                   Сергей Попов   Артем Сенаторов  Настя Рыбка
# Забота                       14                7           13
# Вред                         11                2            1
# Справедливость                4                0            3
# Несправедливость              4               10            3
# Лояльность                    5                1            7
# Нелояльность                  4                1            0
# Уважение                      4               11            4
# Неуважение                    4                1            1
# Чистота                       5                0            0
# Порочность                    1                0            0
# Мораль                        3                2            5

# %%
info_moral.to_csv('info_moral.csv', sep=',')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(info_moral, annot=True, cmap='YlGnBu')
plt.title("Инфоцыгане")
# Out:
# Text(0.5, 1.0, 'Инфоцыгане')

# %%
pip install phik
# Out:
# Collecting phik
#   Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from phik) (1.25.2)
# Requirement already satisfied: scipy>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from phik) (1.11.4)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from phik) (1.5.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from phik) (3.7.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.1->phik) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)
# Installing collected packages: phik
# Successfully installed phik-0.12.4

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
info_moral_phik = info_moral.phik_matrix()
info_moral_phik = info_moral_phik.round(3)
# Out:
# interval columns not set, guessing: ['Боня', 'Яна Рудковская', 'Александра Митрошина', 'Валерия Чекалина', 'Гоар', 'Гусейн Гасанов', 'Оксана Самойлова', 'Аяз Шабутдинов', 'Андрей Петров', 'Алекс Лесли', 'Елена Блиновская', 'Анастасия Шевченко', 'Лев Вожеватов', 'Сергей Попов ', 'Артем Сенаторов', 'Настя Рыбка']

# %%
import numpy as np
import seaborn as sns

# %%
info_moral_phik
# Out:
#                        Боня  Яна Рудковская  Александра Митрошина  \
# Боня                  1.000           0.919                 0.885
# Яна Рудковская        0.919           1.000                 0.903
# Александра Митрошина  0.885           0.903                 1.000
# Валерия Чекалина      0.885           0.903                 0.981
# Гоар                  0.577           0.704                 0.836
# Гусейн Гасанов        0.715           0.786                 0.742
# Оксана Самойлова      0.745           0.793                 0.704
# Аяз Шабутдинов        0.777           0.903                 0.538
# Андрей Петров         0.962           0.971                 0.981
# Алекс Лесли           0.885           0.967                 0.690
# Елена Блиновская      0.989           0.952                 0.965
# Анастасия Шевченко    0.752           0.819                 0.775
# Лев Вожеватов         0.689           0.780                 0.615
# Сергей Попов          0.780           0.542                 0.000
# Артем Сенаторов       0.962           0.919                 0.885
# Настя Рыбка           0.784           0.835                 0.745
#
#                       Валерия Чекалина   Гоар  Гусейн Гасанов  \
# Боня                             0.885  0.577           0.715
# Яна Рудковская                   0.903  0.704           0.786
# Александра Митрошина             0.981  0.836           0.742
# Валерия Чекалина                 1.000  0.682           0.786
# Гоар                             0.682  1.000           0.917
# Гусейн Гасанов                   0.786  0.917           1.000
# Оксана Самойлова                 0.559  0.536           0.723
# Аяз Шабутдинов                   0.707  0.129           0.518
# Андрей Петров                    0.981  0.704           0.786
# Алекс Лесли                      0.829  0.247           0.742
# Елена Блиновская                 0.965  0.645           0.820
# Анастасия Шевченко               0.850  0.000           1.000
# Лев Вожеватов                    0.657  0.000           0.937
# Сергей Попов                     0.599  0.882           0.861
# Артем Сенаторов                  0.919  0.732           1.000
# Настя Рыбка                      0.628  0.634           0.723
#
#                       Оксана Самойлова  Аяз Шабутдинов  Андрей Петров  \
# Боня                             0.745           0.777          0.962
# Яна Рудковская                   0.793           0.903          0.971
# Александра Митрошина             0.704           0.538          0.981
# Валерия Чекалина                 0.559           0.707          0.981
# Гоар                             0.536           0.129          0.704
# Гусейн Гасанов                   0.723           0.518          0.786
# Оксана Самойлова                 1.000           0.673          0.689
# Аяз Шабутдинов                   0.673           1.000          0.804
# Андрей Петров                    0.689           0.804          1.000
# Алекс Лесли                      0.586           0.690          0.829
# Елена Блиновская                 0.722           0.885          0.994
# Анастасия Шевченко               0.853           0.709          0.819
# Лев Вожеватов                    0.306           0.937          0.780
# Сергей Попов                     0.656           0.275          0.542
# Артем Сенаторов                  0.745           0.777          0.919
# Настя Рыбка                      0.796           0.793          0.835
#
#                       Алекс Лесли  Елена Блиновская  Анастасия Шевченко  \
# Боня                        0.885             0.989               0.752
# Яна Рудковская              0.967             0.952               0.819
# Александра Митрошина        0.690             0.965               0.775
# Валерия Чекалина            0.829             0.965               0.850
# Гоар                        0.247             0.645               0.000
# Гусейн Гасанов              0.742             0.820               1.000
# Оксана Самойлова            0.586             0.722               0.853
# Аяз Шабутдинов              0.690             0.885               0.709
# Андрей Петров               0.829             0.994               0.819
# Алекс Лесли                 1.000             0.878               0.775
# Елена Блиновская            0.878             1.000               0.886
# Анастасия Шевченко          0.775             0.886               1.000
# Лев Вожеватов               0.615             0.866               0.829
# Сергей Попов                0.817             0.568               0.000
# Артем Сенаторов             0.885             0.954               0.752
# Настя Рыбка                 0.557             0.856               0.905
#
#                       Лев Вожеватов  Сергей Попов   Артем Сенаторов  \
# Боня                          0.689          0.780            0.962
# Яна Рудковская                0.780          0.542            0.919
# Александра Митрошина          0.615          0.000            0.885
# Валерия Чекалина              0.657          0.599            0.919
# Гоар                          0.000          0.882            0.732
# Гусейн Гасанов                0.937          0.861            1.000
# Оксана Самойлова              0.306          0.656            0.745
# Аяз Шабутдинов                0.937          0.275            0.777
# Андрей Петров                 0.780          0.542            0.919
# Алекс Лесли                   0.615          0.817            0.885
# Елена Блиновская              0.866          0.568            0.954
# Анастасия Шевченко            0.829          0.000            0.752
# Лев Вожеватов                 1.000          0.000            0.689
# Сергей Попов                  0.000          1.000            0.851
# Артем Сенаторов               0.689          0.851            1.000
# Настя Рыбка                   0.783          0.532            0.605
#
#                       Настя Рыбка
# Боня                        0.784
# Яна Рудковская              0.835
# Александра Митрошина        0.745
# Валерия Чекалина            0.628
# Гоар                        0.634
# Гусейн Гасанов              0.723
# Оксана Самойлова            0.796
# Аяз Шабутдинов              0.793
# Андрей Петров               0.835
# Алекс Лесли                 0.557
# Елена Блиновская            0.856
# Анастасия Шевченко          0.905
# Лев Вожеватов               0.783
# Сергей Попов                0.532
# Артем Сенаторов             0.605
# Настя Рыбка                 1.000

# %%
mask = np.triu(np.ones_like(info_moral_phik, dtype=bool))
plt.figure(figsize=(8, 6))
sns.heatmap(info_moral_phik, annot=True, cmap='coolwarm', mask=mask)
plt.show()

# %%
info_moral_pirson = info_moral.corr().round(3)
mask = np.triu(np.ones_like(info_moral_pirson, dtype=bool))
plt.figure(figsize=(8, 6))
sns.heatmap(info_moral_pirson, annot=True, cmap='coolwarm', mask=mask)
plt.show()

# %%
info_moral_pirson
# Out:
#                        Боня  Яна Рудковская  Александра Митрошина  \
# Боня                  1.000           0.968                 0.857
# Яна Рудковская        0.968           1.000                 0.934
# Александра Митрошина  0.857           0.934                 1.000
# Валерия Чекалина      0.891           0.953                 0.929
# Гоар                  0.850           0.872                 0.851
# Гусейн Гасанов        0.961           0.984                 0.908
# Оксана Самойлова      0.974           0.954                 0.897
# Аяз Шабутдинов        0.751           0.741                 0.564
# Андрей Петров         0.923           0.945                 0.925
# Алекс Лесли           0.931           0.948                 0.820
# Елена Блиновская      0.977           0.980                 0.903
# Анастасия Шевченко    0.895           0.900                 0.850
# Лев Вожеватов         0.699           0.657                 0.553
# Сергей Попов          0.777           0.721                 0.646
# Артем Сенаторов       0.538           0.495                 0.373
# Настя Рыбка           0.832           0.883                 0.807
#
#                       Валерия Чекалина   Гоар  Гусейн Гасанов  \
# Боня                             0.891  0.850           0.961
# Яна Рудковская                   0.953  0.872           0.984
# Александра Митрошина             0.929  0.851           0.908
# Валерия Чекалина                 1.000  0.810           0.955
# Гоар                             0.810  1.000           0.831
# Гусейн Гасанов                   0.955  0.831           1.000
# Оксана Самойлова                 0.882  0.842           0.933
# Аяз Шабутдинов                   0.657  0.572           0.736
# Андрей Петров                    0.963  0.792           0.950
# Алекс Лесли                      0.867  0.759           0.963
# Елена Блиновская                 0.934  0.857           0.983
# Анастасия Шевченко               0.906  0.716           0.924
# Лев Вожеватов                    0.649  0.620           0.650
# Сергей Попов                     0.640  0.605           0.719
# Артем Сенаторов                  0.527  0.220           0.545
# Настя Рыбка                      0.799  0.808           0.821
#
#                       Оксана Самойлова  Аяз Шабутдинов  Андрей Петров  \
# Боня                             0.974           0.751          0.923
# Яна Рудковская                   0.954           0.741          0.945
# Александра Митрошина             0.897           0.564          0.925
# Валерия Чекалина                 0.882           0.657          0.963
# Гоар                             0.842           0.572          0.792
# Гусейн Гасанов                   0.933           0.736          0.950
# Оксана Самойлова                 1.000           0.695          0.936
# Аяз Шабутдинов                   0.695           1.000          0.704
# Андрей Петров                    0.936           0.704          1.000
# Алекс Лесли                      0.875           0.773          0.847
# Елена Блиновская                 0.966           0.726          0.959
# Анастасия Шевченко               0.910           0.749          0.975
# Лев Вожеватов                    0.700           0.772          0.749
# Сергей Попов                     0.766           0.345          0.651
# Артем Сенаторов                  0.515           0.815          0.613
# Настя Рыбка                      0.817           0.773          0.810
#
#                       Алекс Лесли  Елена Блиновская  Анастасия Шевченко  \
# Боня                        0.931             0.977               0.895
# Яна Рудковская              0.948             0.980               0.900
# Александра Митрошина        0.820             0.903               0.850
# Валерия Чекалина            0.867             0.934               0.906
# Гоар                        0.759             0.857               0.716
# Гусейн Гасанов              0.963             0.983               0.924
# Оксана Самойлова            0.875             0.966               0.910
# Аяз Шабутдинов              0.773             0.726               0.749
# Андрей Петров               0.847             0.959               0.975
# Алекс Лесли                 1.000             0.934               0.828
# Елена Блиновская            0.934             1.000               0.934
# Анастасия Шевченко          0.828             0.934               1.000
# Лев Вожеватов               0.565             0.733               0.776
# Сергей Попов                0.691             0.697               0.629
# Артем Сенаторов             0.522             0.521               0.694
# Настя Рыбка                 0.792             0.824               0.785
#
#                       Лев Вожеватов  Сергей Попов   Артем Сенаторов  \
# Боня                          0.699          0.777            0.538
# Яна Рудковская                0.657          0.721            0.495
# Александра Митрошина          0.553          0.646            0.373
# Валерия Чекалина              0.649          0.640            0.527
# Гоар                          0.620          0.605            0.220
# Гусейн Гасанов                0.650          0.719            0.545
# Оксана Самойлова              0.700          0.766            0.515
# Аяз Шабутдинов                0.772          0.345            0.815
# Андрей Петров                 0.749          0.651            0.613
# Алекс Лесли                   0.565          0.691            0.522
# Елена Блиновская              0.733          0.697            0.521
# Анастасия Шевченко            0.776          0.629            0.694
# Лев Вожеватов                 1.000          0.177            0.676
# Сергей Попов                  0.177          1.000            0.228
# Артем Сенаторов               0.676          0.228            1.000
# Настя Рыбка                   0.630          0.601            0.415
#
#                       Настя Рыбка
# Боня                        0.832
# Яна Рудковская              0.883
# Александра Митрошина        0.807
# Валерия Чекалина            0.799
# Гоар                        0.808
# Гусейн Гасанов              0.821
# Оксана Самойлова            0.817
# Аяз Шабутдинов              0.773
# Андрей Петров               0.810
# Алекс Лесли                 0.792
# Елена Блиновская            0.824
# Анастасия Шевченко          0.785
# Лев Вожеватов               0.630
# Сергей Попов                0.601
# Артем Сенаторов             0.415
# Настя Рыбка                 1.000

# %%
result_df
# Out:
#                       Забота  Вред  Справедливость  Несправедливость  \
# Боня                      36     7               1                 7
# Яна Рудковская            22     1               3                 4
# Александра Митрошина      10     0               4                 3
# Валерия Чекалина          24     0               5                 9
# Гоар                       9     0               2                 1
# Гусейн Гасанов             5     0               0                 1
# Оксана Самойлова          16     4               3                 5
# Аяз Шабутдинов            11     0               0                 5
# Андрей Петров             32     2               5                16
# Алекс Лесли               16     1               0                 1
# Елена Блиновская          40     2               1                10
# Анастасия Шевченко        43     4               1                26
# Лев Вожеватов             14     0               1                12
# Сергей Попов              14    11               4                 4
# Артем Сенаторов            7     2               0                10
# Настя Рыбка               13     1               3                 3
#
#                       Лояльность  Нелояльность  Уважение  Неуважение  Чистота  \
# Боня                           0             0         9           0        0
# Яна Рудковская                 2             1         5           1        0
# Александра Митрошина           1             1         1           0        1
# Валерия Чекалина               2             2         5           6        1
# Гоар                           1             0         1           1        3
# Гусейн Гасанов                 0             0         1           0        0
# Оксана Самойлова               1             3         4           0        1
# Аяз Шабутдинов                 4             0        11           0        0
# Андрей Петров                  2             2         6           2        0
# Алекс Лесли                    1             1         6           0        0
# Елена Блиновская               0             3         7           0        0
# Анастасия Шевченко             6             6        11           0        1
# Лев Вожеватов                  2             3         8           3        1
# Сергей Попов                   5             4         4           4        5
# Артем Сенаторов                1             1        11           1        0
# Настя Рыбка                    7             0         4           1        0
#
#                       Порочность  Мораль
# Боня                           0       8
# Яна Рудковская                 0       3
# Александра Митрошина           0       1
# Валерия Чекалина               0       2
# Гоар                           0       4
# Гусейн Гасанов                 0       0
# Оксана Самойлова               0       5
# Аяз Шабутдинов                 1       5
# Андрей Петров                  0       5
# Алекс Лесли                    2       0
# Елена Блиновская               2       7
# Анастасия Шевченко             0       7
# Лев Вожеватов                  4      13
# Сергей Попов                   1       3
# Артем Сенаторов                0       2
# Настя Рыбка                    0       5

# %%
result_df_phik = result_df.phik_matrix()
result_df_phik = result_df_phik.round(3)
# Out:
# interval columns not set, guessing: ['Забота', 'Вред', 'Справедливость', 'Несправедливость', 'Лояльность', 'Нелояльность', 'Уважение', 'Неуважение', 'Чистота', 'Порочность', 'Мораль']

# %%
result_df_phik
# Out:
#                   Забота   Вред  Справедливость  Несправедливость  Лояльность  \
# Забота             1.000  0.519           0.612             0.715       0.000
# Вред               0.519  1.000           0.000             0.758       0.559
# Справедливость     0.612  0.000           1.000             0.000       0.275
# Несправедливость   0.715  0.758           0.000             1.000       0.401
# Лояльность         0.000  0.559           0.275             0.401       1.000
# Нелояльность       0.260  0.636           0.810             0.598       0.770
# Уважение           0.872  0.551           0.000             0.789       0.000
# Неуважение         0.602  0.441           0.773             0.662       0.434
# Чистота            0.000  0.634           0.776             0.000       0.597
# Порочность         0.000  0.000           0.000             0.613       0.441
# Мораль             0.739  0.609           0.173             0.957       0.000
#
#                   Нелояльность  Уважение  Неуважение  Чистота  Порочность  \
# Забота                   0.260     0.872       0.602    0.000       0.000
# Вред                     0.636     0.551       0.441    0.634       0.000
# Справедливость           0.810     0.000       0.773    0.776       0.000
# Несправедливость         0.598     0.789       0.662    0.000       0.613
# Лояльность               0.770     0.000       0.434    0.597       0.441
# Нелояльность             1.000     0.000       0.870    0.698       0.310
# Уважение                 0.000     1.000       0.454    0.000       0.899
# Неуважение               0.870     0.454       1.000    0.726       0.747
# Чистота                  0.698     0.000       0.726    1.000       0.578
# Порочность               0.310     0.899       0.747    0.578       1.000
# Мораль                   0.445     0.760       0.638    0.000       0.613
#
#                   Мораль
# Забота             0.739
# Вред               0.609
# Справедливость     0.173
# Несправедливость   0.957
# Лояльность         0.000
# Нелояльность       0.445
# Уважение           0.760
# Неуважение         0.638
# Чистота            0.000
# Порочность         0.613
# Мораль             1.000

# %%
mask = np.triu(np.ones_like(result_df_phik, dtype=bool))
plt.figure(figsize=(8, 6))
sns.heatmap(result_df_phik, annot=True, cmap='coolwarm', mask=mask)
plt.show()
