# %% [markdown]
# <a href="https://colab.research.google.com/github/artigenius/portfolio/blob/main/sort_by_years.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Очистка и обработка данных

# %% [markdown]
# Загрузить таблицу и очистить данные

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/songs_texts.csv')
# отобразим полученные данные
df.head(5)
df.tail(5)
# Out:
#        df_id        id    year  \
# 7334  374004   4379441  1989.0
# 7335  374978  17087001  1989.0
# 7336  374983  17087001  1989.0
# 7337  374998   7798352  1989.0
# 7338  375018  13089117  1989.0
#
#                                                     uri       artists_text  \
# 7334  https://www.discogs.com/release/4379441-%D0%92...  Владимир Высоцкий
# 7335  https://www.discogs.com/release/17087001-%D0%9...       Петр Лещенко
# 7336  https://www.discogs.com/release/17087001-%D0%9...       Петр Лещенко
# 7337  https://www.discogs.com/release/7798352-%D0%9F...       Петр Лещенко
# 7338  https://www.discogs.com/release/13089117-%D0%9...       Петр Лещенко
#
#                   track_title country released  \
# 7334  Все Срока Уже Закончены    USSR     1989
# 7335               Два Сердца    USSR     1989
# 7336             Играй, Цыган    USSR     1989
# 7337            Признайся Мне    USSR     1989
# 7338                  Лошадки    USSR     1989
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7339 entries, 0 to 7338
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   df_id         7339 non-null   int64
#  1   id            7339 non-null   int64
#  2   year          6431 non-null   float64
#  3   uri           7339 non-null   object
#  4   artists_text  7339 non-null   object
#  5   track_title   7337 non-null   object
#  6   country       7314 non-null   object
#  7   released      6431 non-null   object
#  8   genres        7339 non-null   object
#  9   styles        5864 non-null   object
#  10  track_mid     7339 non-null   object
#  11  written_by    383 non-null    object
#  12  music_by      1799 non-null   object
#  13  composed_by   63 non-null     object
#  14  lyrics_by     1288 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 860.2+ KB

# %%
df_clean = df[['year', 'track_mid', 'country', 'released']]
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7339 entries, 0 to 7338
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       6431 non-null   float64
#  1   track_mid  7339 non-null   object
#  2   country    7314 non-null   object
#  3   released   6431 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 229.5+ KB

# %%
df_clean.loc[df_clean["year"] == 1990, "track_mid"]
# Out:
# 665                            В Ферапонтов Голубой Вагон
# 3639                Pink Floyd Shine On You Crazy Diamond
# 3640                           Pink Floyd Learning To Fly
# 3641                         Pink Floyd Yet Another Movie
# 3642                          Pink Floyd Round And Around
#                               ...
# 7318                           Александр Вертинский Китеж
# 7319      Александр Вертинский Ваши Пальцы Пахнут Ладаном
# 7320             Александр Вертинский Снежная Колыбельная
# 7321           Александр Вертинский Сумасшедший Шарманщик
# 7322    Александр Вертинский Только Раз Бывают В Жизни...
# Name: track_mid, Length: 207, dtype: object

# %%
year50_name = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] <= 1960), "track_mid"]
year50_name
# Out:
# 6872     Тихон Хренников Музыка К К ф Верные Друзья
# 6873    Тихон Хренников Что Так Сердце Растревожено
# 6874                 Тихон Хренников Речная Песенка
# Name: track_mid, dtype: object

# %%
df_clean["year"].min()
# Out:
# 1959.0

# %%
df_clean["year"].max()
# Out:
# 2020.0

# %% [markdown]
# # Сортировка по годам

# %% [markdown]
# создадим отдельные таблицы по каждому временному периоду

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] <= 1960)]
df50
# Out:
#         year                                    track_mid country released
# 6872  1959.0   Тихон Хренников Музыка К К ф Верные Друзья    USSR     1959
# 6873  1959.0  Тихон Хренников Что Так Сердце Растревожено    USSR     1959
# 6874  1959.0               Тихон Хренников Речная Песенка    USSR     1959

# %%
df50.to_csv("50s.csv")

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] <= 1970)]
df60
# Out:
#         year                            track_mid country released
# 26    1963.0    Robertino Loretti Девочка из Рима    USSR     1963
# 29    1964.0                   Эдита Пьеха Хорошо    USSR     1964
# 31    1964.0             Майя Кристалинская Еду Я    USSR     1964
# 32    1964.0     Майя Кристалинская Листья Кленов    USSR     1964
# 34    1965.0  Раиса Неменова Кружит Дымная Пороша    USSR     1965
# ...      ...                                  ...     ...      ...
# 6947  1970.0               Виктор Лебедев Счастье    USSR     1970
# 6956  1965.0  М Бернес Воспоминание Об Эскадрилье    USSR     1965
# 6959  1969.0             Г Ненашева Любите Россию    USSR     1969
# 6960  1969.0                     ВИО День За Днем    USSR     1969
# 6963  1966.0          В Бунчиков Лирический Вальс    USSR     1966
#
# [728 rows x 4 columns]

# %%
df60.to_csv("60s.csv")

# %%
df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] <= 1980)]
df70
# Out:
#         year                              track_mid country released
# 0     1971.0                 Клавдия Шульженко Руки    USSR     1971
# 1     1971.0       Клавдия Шульженко Синий платочек    USSR     1971
# 2     1971.0       Клавдия Шульженко Прощальный луч    USSR     1971
# 3     1971.0              Клавдия Шульженко Подъезд    USSR     1971
# 4     1971.0        Клавдия Шульженко Песня о любви    USSR     1971
# ...      ...                                    ...     ...      ...
# 7109  1978.0         Андрей Миронов Давай Поговорим    USSR     1978
# 7110  1978.0  Андрей Миронов Воспоминание О Прошлом    USSR     1978
# 7111  1978.0               Андрей Миронов Джон Грей    USSR     1978
# 7112  1978.0                 Андрей Миронов Коломбо    USSR     1978
# 7113  1978.0              Андрей Миронов Таити Трот    USSR     1978
#
# [2461 rows x 4 columns]

# %%
df70.to_csv("70s.csv")

# %%
df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] <= 1990)]
df80
# Out:
#         year                                   track_mid  country released
# 73    1987.0  Dionne Warwick That s What Friends Are For  Estonia     1987
# 74    1987.0                         Chris Rea Lucky Day     USSR     1987
# 75    1987.0                      Chris Rea Hello Friend     USSR     1987
# 76    1987.0                         Chris Rea Two Roads     USSR     1987
# 77    1987.0                Chris Rea Auf Immer Und Ewig     USSR     1987
# ...      ...                                         ...      ...      ...
# 7334  1989.0   Владимир Высоцкий Все Срока Уже Закончены     USSR     1989
# 7335  1989.0                     Петр Лещенко Два Сердца     USSR     1989
# 7336  1989.0                    Петр Лещенко Играй Цыган     USSR     1989
# 7337  1989.0                  Петр Лещенко Признайся Мне     USSR     1989
# 7338  1989.0                        Петр Лещенко Лошадки     USSR     1989
#
# [1962 rows x 4 columns]

# %%
df80.to_csv("80s.csv")

# %%
df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] <= 2000)]
df90
# Out:
#         year                                          track_mid country  \
# 5     1999.0                           О Анофриев Песня о друге  Russia
# 6     1999.0                                   А Герман Надежда  Russia
# 7     1999.0                        М Магомаев Королева красоты  Russia
# 8     1999.0                        М Кристалинская А Снег Идет  Russia
# 9     1999.0                         К Шульженко На Тот Большак  Russia
# ...      ...                                                ...     ...
# 7318  1990.0                         Александр Вертинский Китеж    USSR
# 7319  1990.0    Александр Вертинский Ваши Пальцы Пахнут Ладаном    USSR
# 7320  1990.0           Александр Вертинский Снежная Колыбельная    USSR
# 7321  1990.0         Александр Вертинский Сумасшедший Шарманщик    USSR
# 7322  1990.0  Александр Вертинский Только Раз Бывают В Жизни...    USSR
#
#      released
# 5        1999
# 6        1999
# 7        1999
# 8        1999
# 9        1999
# ...

# %%
df90.to_csv("90s.csv")

# %% [markdown]
# # Страдания с текстами начинаются

# %% [markdown]
# загрузить таблицу с текстами песен, очистить данные, объединить с таблицами по годам

# %% [markdown]
# # 1 таблица

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page1.xlsx', header=0)
df

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page1.csv', index=False)
df

# %%
df.info()

# %%
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean.head()
# Out:
#    year                                     track_mid country  \
# 0  1988                  Осип Мандельштам Автопортрет    USSR
# 1  1988     Осип Мандельштам Звук Осторожный и Глухой    USSR
# 2  1988  Осип Мандельштам Только Детские Книги Читать    USSR
# 3  1988               Осип Мандельштам Нежнее Нежного    USSR
# 4  1988                Осип Мандельштам Дано Мне Тело    USSR
#
#                                          lyrics_text
# 0                                                NaN
# 1                                                NaN
# 2  Только детские книги читать, \nТолько детские ...
# 3  Нежнее нежного\nЛицо твоё,\nБелее белого\nТвоя...
# 4  Дано мне тело — что мне делать с ним,\nТаким е...

# %%
df_clean = df_clean.dropna()
df_clean
# Out:
#        year                                          track_mid country  \
# 2      1988       Осип Мандельштам Только Детские Книги Читать    USSR
# 3      1988                    Осип Мандельштам Нежнее Нежного    USSR
# 4      1988                     Осип Мандельштам Дано Мне Тело    USSR
# 5      1988                         Осип Мандельштам Silentium    USSR
# 6      1988               Осип Мандельштам Сегодня Дурной День    USSR
# ...     ...                                                ...     ...
# 49918  1975                      Георгий Свиридов Время Вперед    USSR
# 49919  1980  Георгий Свиридов Метель Музыкальные Иллюстраци...    USSR
# 49970  1976  Ludwig van Beethoven Sonata No In C Minor Op P...    USSR
# 49971  1976  Ludwig van Beethoven Sonata No In C Sharp Mino...    USSR
# 49972  1976  Ludwig van Beethoven Sonata No In F Minor Op A...    USSR
#
#                                              lyrics_text
# 2      Только детские книги читать, \nТолько детские ...
# ...

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] <= 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] <= 1970)]
df60
# Out:
#        year                          track_mid country  \
# 230    1963  Robertino Loretti Девочка из Рима    USSR
# 269    1964                 Эдита Пьеха Хорошо    USSR
# 286    1965                         Аккорд Эхо    USSR
# 291    1965                     Аккорд Котенок    USSR
# 292    1965                         Аккорд Эхо    USSR
# ...     ...                                ...     ...
# 18552  1968        Antonio Vivaldi Domine Deus    USSR
# 18682  1968         Georges Bizet Кармен Сюита    USSR
# 19268  1969           Лусинэ Закарян Келе Келе    USSR
# 19569  1964               Antonín Dvořák Largo    USSR
# 23200  1968  Franz Liszt Hungarian Rhapsody No    USSR
#
#                                              lyrics_text
# 230    Bambina Bruna\nSono l'ultimo romantica qe cant...
# 269    Это здорово, это здорово, это очень хорошо!\nП...
# 286    Вечером эхо за рекою,\nЗвонкое эхо,лишь с тобо...
# 291    Я пушистый беленький котёнок,\nНе ловил ни раз...
# ...

# %%
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_1.csv', index = False)

# %%
df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] <= 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_1.csv', index = False)
df70
# Out:
#        year                                          track_mid country  \
# 67     1971                        Клавдия Шульженко На санках    USSR
# 68     1971                             Клавдия Шульженко Руки    USSR
# 69     1971                   Клавдия Шульженко Синий платочек    USSR
# 70     1971                 Клавдия Шульженко Приходи поскорей    USSR
# 71     1971                         Клавдия Шульженко Моя тень    USSR
# ...     ...                                                ...     ...
# 49918  1975                      Георгий Свиридов Время Вперед    USSR
# 49919  1980  Георгий Свиридов Метель Музыкальные Иллюстраци...    USSR
# 49970  1976  Ludwig van Beethoven Sonata No In C Minor Op P...    USSR
# 49971  1976  Ludwig van Beethoven Sonata No In C Sharp Mino...    USSR
# 49972  1976  Ludwig van Beethoven Sonata No In F Minor Op A...    USSR
#
#                                              lyrics_text
# 67     • • • • • • • • • • • • • • • • • • • • • • • ...
# ...

# %%
df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_1.csv', index = False)
df80

# %%
df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] <= 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_1.csv', index = False)
df90

# %% [markdown]
# # 2 таблица

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page2.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page2.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] <= 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_2.csv', index = False)
df60

# %%
df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_2.csv', index = False)
df70

# %%
df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_2.csv', index = False)
df80

# %%
df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_2.csv', index = False)
df90

# %% [markdown]
# # 3 таблица

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page3.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page3.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_3.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_3.csv', index = False)

# %%
df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_3.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_3.csv', index = False)

# %% [markdown]
# # 4 таблица

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page4.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page4.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_4.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_4.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_4.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_4.csv', index = False)

# %% [markdown]
# # 5 таблица

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page5.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page5.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_5.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_5.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_5.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_5.csv', index = False)

# %% [markdown]
# # 6

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page6.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page6.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
#        year                                          track_mid country  \
# 44371  1959  საქართველოს ცეკვისა და სიმღერის სახელმწიფო ანს...    USSR
# 44374  1959  საქართველოს ცეკვისა და სიმღერის სახელმწიფო ანს...    USSR
# 44375  1959  საქართველოს ცეკვისა და სიმღერის სახელმწიფო ანს...    USSR
# 44445  1959         Тихон Хренников Музыка К К ф Верные Друзья    USSR
# 44448  1959        Тихон Хренников Что Так Сердце Растревожено    USSR
# 44449  1959                     Тихон Хренников Речная Песенка    USSR
# 44457  1959               Тихон Хренников Колыбельная Светланы    USSR
#
#                                              lyrics_text
# 44371  It’s been a long time wondering\nwhy the summe...
# 44374  щени твалеби ра твалебиа\nщени твалеби гулит в...
# 44375  Гзеби да кучеби,кучеби гзеби да... Ме втовеб б...
# 44445  Что так сердце что так сердце растревожено\nСл...
# 44448  Что так сердце что так сердце растревожено\nСл...
# ...

# %%
df50.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/50_6.csv', index = False)

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_6.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_6.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_6.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_6.csv', index = False)

# %% [markdown]
# # 7

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page7.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page7.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_7.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_7.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_7.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_7.csv', index = False)

# %% [markdown]
# # 8

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page8.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page8.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_8.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_8.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_8.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_8.csv', index = False)

# %% [markdown]
# # 9

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page9.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page9.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_9.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_9.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_9.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_9.csv', index = False)

# %% [markdown]
# # 10

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page10.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page10.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_10.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_10.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_10.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_10.csv', index = False)

# %% [markdown]
# # 11

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page11.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page11.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_11.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_11.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_11.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_11.csv', index = False)

# %% [markdown]
# # 12

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page12.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page12.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_12.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_12.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_12.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_12.csv', index = False)

# %% [markdown]
# # 13

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page13.xlsx', header=0)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/tracks_with_lyrics_page13.csv', index=False)
df_clean = df[['year', 'track_mid', 'country', 'lyrics_text']]
df_clean = df_clean.dropna()

# %%
df50 = df_clean.loc[(df_clean["year"] >= 1950) & (df_clean["year"] < 1960)]
df50
# Out:
# Empty DataFrame
# Columns: [year, track_mid, country, lyrics_text]
# Index: []

# %%
df60 = df_clean.loc[(df_clean["year"] >= 1960) & (df_clean["year"] < 1970)]
df60.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_13.csv', index = False)

df70 = df_clean.loc[(df_clean["year"] >= 1970) & (df_clean["year"] < 1980)]
df70.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_13.csv', index = False)

df80 = df_clean.loc[(df_clean["year"] >= 1980) & (df_clean["year"] < 1990)]
df80.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_13.csv', index = False)

df90 = df_clean.loc[(df_clean["year"] >= 1990) & (df_clean["year"] < 2000)]
df90.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_13.csv', index = False)

# %% [markdown]
# # Рейнджеры мы едины

# %%
df601 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_1.csv')
df602 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_2.csv')
df603=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_3.csv')
df604=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_4.csv')
df605=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_5.csv')
df606=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_6.csv')
df607=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_7.csv')
df608=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_8.csv')
df609=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_9.csv')
df610=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_10.csv')
df611=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_11.csv')
df612=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_12.csv')
df613=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_13.csv')

# %%
df60_12=df601.append(df602, sort=False)
df60_12

# %%
frames = [df601, df602, df603, df604, df605, df606, df607, df608, df609, df610, df611, df612, df613]
result = pd.concat(frames)
result
# Out:
#      year                           track_mid country  \
# 0    1971         Клавдия Шульженко На санках    USSR
# 1    1971              Клавдия Шульженко Руки    USSR
# 2    1971    Клавдия Шульженко Синий платочек    USSR
# 3    1971  Клавдия Шульженко Приходи поскорей    USSR
# 4    1971          Клавдия Шульженко Моя тень    USSR
# ..    ...                                 ...     ...
# 212  1978    Изабелла Юрьева О любви и дружбе    USSR
# 213  1978     Изабелла Юрьева Ласково взгляни    USSR
# 214  1978    Изабелла Юрьева Я так любила вас    USSR
# 215  1979        Мария Наровская Я Старше Вас    USSR
# 216  1979             Мария Наровская Караван    USSR
#
#                                            lyrics_text
# 0    • • • • • • • • • • • • • • • • • • • • • • • ...
# 1    Слова: В. Лебедев-Кумач \nМузыка: И. Жак \nИсп...
# 2    Синенький скромный платочек\nПадал с опущенных...
# 3    • • • • • • • • • • • • • • • • • • • • • • • ...
# ...

# %%
result.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60s_texts.csv', index = False)

# %% [markdown]
# вперед вперед

# %%
df701=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_1.csv')
df702=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_2.csv')
df703=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_3.csv')
df704=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_4.csv')
df705=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_5.csv')
df706=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_6.csv')
df707=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_7.csv')
df708=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_8.csv')
df709=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_9.csv')
df710=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_10.csv')
df711=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_11.csv')
df712=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_12.csv')
df713=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_13.csv')

# %%
frames = [df701, df702, df703, df704, df705, df706, df707, df708, df709, df710, df711, df712, df713]
result = pd.concat(frames)
result.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70s_texts.csv', index = False)

# %% [markdown]
# вперед вперед вперед

# %%
df801=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_1.csv')
df802=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_2.csv')
df803=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_3.csv')
df804=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_4.csv')
df805=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_5.csv')
df806=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_6.csv')
df807=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_7.csv')
df808=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_8.csv')
df809=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_9.csv')
df810=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_10.csv')
df811=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_11.csv')
df812=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_12.csv')
df813=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_13.csv')

# %%
frames = [df801, df802, df803, df804, df805, df806, df807, df808, df809, df810, df811, df812, df813]
result = pd.concat(frames)
result.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80s_texts.csv', index = False)

# %% [markdown]
# вперед вперде

# %%
df901=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_1.csv')
df902=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_2.csv')
df903=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_3.csv')
df904=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_4.csv')
df905=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_5.csv')
df906=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_6.csv')
df907=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_7.csv')
df908=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_8.csv')
df909=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_9.csv')
df910=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_10.csv')
df911=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_11.csv')
df912=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_12.csv')
df913=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_13.csv')

# %%
frames = [df901, df902, df903, df904, df905, df906, df907, df908, df909, df910, df911, df912, df913]
result = pd.concat(frames)
result.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90s_texts.csv', index = False)

# %% [markdown]
# # Начинаем чистку текстов от иностранной музыки

# %%
df_60_text=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60s_texts.csv')
df_70_text=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70s_texts.csv')
df_80_text=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80s_texts.csv')
df_90_text=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90s_texts.csv')

# %%
df_60_text.head()
# Out:
#    year                          track_mid country  \
# 0  1963  Robertino Loretti Девочка из Рима    USSR
# 1  1964                 Эдита Пьеха Хорошо    USSR
# 2  1965                         Аккорд Эхо    USSR
# 3  1965                     Аккорд Котенок    USSR
# 4  1965                         Аккорд Эхо    USSR
#
#                                          lyrics_text
# 0  Bambina Bruna\nSono l'ultimo romantica qe cant...
# 1  Это здорово, это здорово, это очень хорошо!\nП...
# 2  Вечером эхо за рекою,\nЗвонкое эхо,лишь с тобо...
# 3  Я пушистый беленький котёнок,\nНе ловил ни раз...
# 4  Вечером эхо за рекою,\nЗвонкое эхо,лишь с тобо...

# %%
! pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=1af0c433a70dd4c9fafbf6763492378f5a5a354049bad49bc7208a0006937df3
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
from langdetect import detect as ft

# %%
df_60_text['lyrics_text'] = df_60_text['lyrics_text'].astype('string')
df_60_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5951 entries, 0 to 5950
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         5951 non-null   int64
#  1   track_mid    5951 non-null   object
#  2   country      5951 non-null   object
#  3   lyrics_text  5951 non-null   string
# dtypes: int64(1), object(2), string(1)
# memory usage: 186.1+ KB

# %%
lang_60 = df_60_text['lyrics_text'].apply(ft)
lang_60=lang_60.rename('language')

# %%
df_60_text = pd.concat([df_60_text, lang_60], axis=1)
df_60_text
# Out:
#       year                           track_mid country  \
# 0     1963   Robertino Loretti Девочка из Рима    USSR
# 1     1964                  Эдита Пьеха Хорошо    USSR
# 2     1965                          Аккорд Эхо    USSR
# 3     1965                      Аккорд Котенок    USSR
# 4     1965                          Аккорд Эхо    USSR
# ...    ...                                 ...     ...
# 5946  1966           Георг Отс Черное Море Мое    USSR
# 5947  1966  Эдуард Хиль Как Провожают Пароходы    USSR
# 5948  1969  Franz Lehár Оперетта Веселая Вдова    USSR
# 5949  1969   Муслим Магомаев Влюбленный Солдат    USSR
# 5950  1969                Муслим Магомаев Мама    USSR
#
#                                             lyrics_text language
# 0     Bambina Bruna\nSono l'ultimo romantica qe cant...       it
# 1     Это здорово, это здорово, это очень хорошо!\nП...       ru
# 2     Вечером эхо за рекою,\nЗвонкое эхо,лишь с тобо...       ru
# ...

# %%
df_60_text_ru = df_60_text[df_70_text['language'] == 'ru']
df_60_text_ru
# Out:
# <ipython-input-236-7556c347567a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_60_text_ru = df_60_text[df_70_text['language'] == 'ru']
#       year                           track_mid country  \
# 0     1963   Robertino Loretti Девочка из Рима    USSR
# 1     1964                  Эдита Пьеха Хорошо    USSR
# 2     1965                          Аккорд Эхо    USSR
# 3     1965                      Аккорд Котенок    USSR
# 4     1965                          Аккорд Эхо    USSR
# ...    ...                                 ...     ...
# 5944  1966           Георг Отс Черное Море Мое    USSR
# 5945  1966  Эдуард Хиль Как Провожают Пароходы    USSR
# 5948  1969  Franz Lehár Оперетта Веселая Вдова    USSR
# 5949  1969   Муслим Магомаев Влюбленный Солдат    USSR
# 5950  1969                Муслим Магомаев Мама    USSR
#
#                                             lyrics_text language
# 0     Bambina Bruna\nSono l'ultimo romantica qe cant...       it
# ...

# %%
df_60_text_ru.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/60_texts_ru.csv', index = False)

# %% [markdown]
# я щас заплачу наконец-то

# %%
df_70_text['lyrics_text'] = df_70_text['lyrics_text'].astype('string')

lang_70 = df_70_text['lyrics_text'].apply(ft)
lang_70=lang_70.rename('language')

df_70_text = pd.concat([df_70_text, lang_70], axis=1)

df_70_text
# Out:
#        year                           track_mid country  \
# 0      1971         Клавдия Шульженко На санках    USSR
# 1      1971              Клавдия Шульженко Руки    USSR
# 2      1971    Клавдия Шульженко Синий платочек    USSR
# 3      1971  Клавдия Шульженко Приходи поскорей    USSR
# 4      1971          Клавдия Шульженко Моя тень    USSR
# ...     ...                                 ...     ...
# 19050  1978    Изабелла Юрьева О любви и дружбе    USSR
# 19051  1978     Изабелла Юрьева Ласково взгляни    USSR
# 19052  1978    Изабелла Юрьева Я так любила вас    USSR
# 19053  1979        Мария Наровская Я Старше Вас    USSR
# 19054  1979             Мария Наровская Караван    USSR
#
#                                              lyrics_text language
# 0      • • • • • • • • • • • • • • • • • • • • • • • ...       ru
# 1      Слова: В. Лебедев-Кумач
# Музыка: И. Жак
# Исп.:...       ru
# 2      Синенький скромный платочек
# Падал с опущенных ...       ru
# ...

# %%
df_70_text_ru = df_70_text[df_70_text['language'] == 'ru']
df_70_text_ru
# Out:
#        year                           track_mid country  \
# 0      1971         Клавдия Шульженко На санках    USSR
# 1      1971              Клавдия Шульженко Руки    USSR
# 2      1971    Клавдия Шульженко Синий платочек    USSR
# 3      1971  Клавдия Шульженко Приходи поскорей    USSR
# 4      1971          Клавдия Шульженко Моя тень    USSR
# ...     ...                                 ...     ...
# 19050  1978    Изабелла Юрьева О любви и дружбе    USSR
# 19051  1978     Изабелла Юрьева Ласково взгляни    USSR
# 19052  1978    Изабелла Юрьева Я так любила вас    USSR
# 19053  1979        Мария Наровская Я Старше Вас    USSR
# 19054  1979             Мария Наровская Караван    USSR
#
#                                              lyrics_text language
# 0      • • • • • • • • • • • • • • • • • • • • • • • ...       ru
# 1      Слова: В. Лебедев-Кумач
# Музыка: И. Жак
# Исп.:...       ru
# 2      Синенький скромный платочек
# Падал с опущенных ...       ru
# ...

# %%
df_70_text_ru.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/70_texts_ru.csv', index = False)

# %%
df_80_text['lyrics_text'] = df_80_text['lyrics_text'].astype('string')

lang_80 = df_80_text['lyrics_text'].apply(ft)
lang_80=lang_80.rename('language')

df_80_text = pd.concat([df_80_text, lang_80], axis=1)

# %%
df_80_text_ru = df_80_text[df_80_text['language'] == 'ru']
df_80_text_ru
# Out:
#        year                                     track_mid country  \
# 0      1988  Осип Мандельштам Только Детские Книги Читать    USSR
# 1      1988               Осип Мандельштам Нежнее Нежного    USSR
# 2      1988                Осип Мандельштам Дано Мне Тело    USSR
# 3      1988                    Осип Мандельштам Silentium    USSR
# 4      1988          Осип Мандельштам Сегодня Дурной День    USSR
# ...     ...                                           ...     ...
# 18585  1989                             Петр Лещенко Катя    USSR
# 18586  1989                       Петр Лещенко Два Сердца    USSR
# 18587  1989                           Петр Лещенко Чубчик    USSR
# 18588  1989                  Петр Лещенко Мусенька Родная    USSR
# 18589  1989                      Петр Лещенко Играй Цыган    USSR
#
#                                              lyrics_text language
# 0      Только детские книги читать,
# Только детские д...       ru
# 1      Нежнее нежного
# Лицо твоё,
# ...

# %%
df_80_text_ru.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/80_texts_ru.csv', index = False)

# %%
df_90_text['lyrics_text'] = df_90_text['lyrics_text'].astype('string')

lang_90 = df_90_text['lyrics_text'].apply(ft)
lang_90=lang_90.rename('language')

df_90_text = pd.concat([df_90_text, lang_90], axis=1)

# %%
df_90_text_ru = df_90_text[df_90_text['language'] == 'ru']
df_90_text_ru
# Out:
#       year                     track_mid country  \
# 0     1999      О Анофриев Песня о друге  Russia
# 1     1999              А Герман Надежда  Russia
# 2     1999      Л Утесов Московские окна  Russia
# 3     1999          Г Великанова Ландыши  Russia
# 4     1999   М Магомаев Королева красоты  Russia
# ...    ...                           ...     ...
# 6101  1991             Петр Лещенко Катя    USSR
# 6102  1991       Петр Лещенко Два Сердца    USSR
# 6103  1991           Петр Лещенко Чубчик    USSR
# 6104  1991  Петр Лещенко Мусенька Родная    USSR
# 6105  1991      Петр Лещенко Играй Цыган    USSR
#
#                                             lyrics_text language
# 0     Если радость на всех одна, на всех и беда одна...       ru
# 1     Надежда
# Слова Николая Добронравова
# Музыка Алек...       ru
# 2     • • • • • • • • • • • • • • • • • • • • • • • ...       ru
# 3     • • • • • • • • • • • • • • • • • • • • • • • ...       ru
# 4     По переулкам бродит лето
# ...

# %%
df_90_text_ru.to_csv('/content/drive/MyDrive/Colab Notebooks/проект песни/90_texts_ru.csv', index = False)
